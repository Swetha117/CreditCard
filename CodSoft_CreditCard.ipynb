# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
dt=pd.read_csv("/content/creditcard.csv")

# %%
dt.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dt.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  164534.000000  164533.000000  164533.000000  164533.000000
# mean    58866.836757      -0.191243       0.050156       0.537739
# std     25904.273879       1.845074       1.609273       1.366180
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     40551.500000      -0.997891      -0.529803      -0.002542
# 50%     59332.000000      -0.211344       0.117315       0.654755
# 75%     76911.750000       1.177607       0.809125       1.314853
# max    116787.000000       2.439207      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  164533.000000  164533.000000  164533.000000  164533.000000
# mean        0.130029      -0.194730       0.062812      -0.089545
# std         1.366289       1.333955       1.292413       1.206277
# min        -5.519697     -42.147898     -26.160506     -43.557242
# ...

# %%
dt.isnull().sum()
# Out:
# Time      0
# V1        1
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
dt=dt.fillna(0)

# %%
dt.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dt.value_counts()
# Out:
# Time      V1          V2          V3         V4         V5         V6         V7          V8          V9         V10         V11        V12        V13        V14        V15        V16        V17        V18        V19        V20        V21         V22        V23        V24        V25        V26        V27        V28        Amount  Class
# 43153.0   -2.086016    2.203265    1.654339   2.941050  -1.683045   0.529728  -1.352162    1.793449   -0.723686   0.600365   -0.982212  -0.551636  -1.337000   0.834403   1.251862   0.033455   1.067978   0.160510   0.213087   0.079002   0.216444    0.567241  -0.035345   0.370201   0.157378   0.440341   0.210230   0.090558  0.76    0.0      9
# ...

# %%
dt['Class'].value_counts()
# Out:
# 0.0    164175
# 1.0       358
# Name: Class, dtype: int64

# %%
x=dt[dt.Class==0]
y=dt[dt.Class==1]

# %%
print(x.shape)
# Out:
# (164175, 31)

# %%
print(y.shape)
# Out:
# (358, 31)

# %%
x.Amount.describe()
# Out:
# count    164175.000000
# mean         86.820967
# std         243.643211
# min           0.000000
# 25%           5.380000
# 50%          21.400000
# 75%          76.050000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
y.Amount.describe()
# Out:
# count     358.000000
# mean      111.608492
# std       227.944683
# min         0.000000
# 25%         1.000000
# 50%        10.685000
# 75%       101.500000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
dt.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    58872.073428 -0.178522  0.040668  0.556318  0.119665 -0.185595
# 1.0    56303.567039 -6.025123  4.401259 -7.982396  4.882663 -4.383916
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.066107 -0.074407  0.036958  0.027768  ...  0.032363 -0.034722
# 1.0   -1.448126 -7.031758  0.774862 -2.874111  ...  0.413668  0.766540
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.093217 -0.024447  0.010315  0.100571  0.013669  0.001892  0.002312
# 1.0   -0.017387 -0.044248 -0.075042  0.080196  0.036588  0.182343  0.044561
#
#            Amount
# Class
# 0.0     86.820967
# 1.0    111.608492
#
# [2 rows x 30 columns]

# %%
x_reduced=x.sample(n=358)

# %%
print(x_reduced.shape)
print(y.shape)
# Out:
# (358, 31)
# (358, 31)

# %%
new_dt=pd.concat([x_reduced,y],axis=0)

# %%
new_dt
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 66819    52234.0  1.213291  0.226833  0.255260  0.654018 -0.283934 -0.629686
# 18551    29590.0  1.404845 -0.958269 -0.613266 -1.797737  1.009978  3.535838
# 26740    34228.0 -0.029427  0.354226 -0.119607 -2.096272  0.698008 -0.559983
# 78087    57366.0  1.118602 -0.253348  1.339775  0.805368 -1.189316 -0.115294
# 99126    66975.0  1.217849 -0.776929  0.099732 -0.488724 -1.158348 -1.126549
# ...          ...       ...       ...       ...       ...       ...       ...
# 157868  110547.0 -1.532810  2.232752 -5.923100  3.386708 -0.153443 -1.419748
# 157871  110552.0 -2.450367  2.107729 -5.140663  1.411304 -1.690780 -0.736427
# 157918  110617.0 -1.101035 -1.674928 -0.573388  5.617556  0.765556  0.440607
# 163149  115691.0 -1.550273  1.088689 -2.393388  1.008733 -1.087562 -1.104602
# 163586  116067.0  0.949241  1.333519 -4.855402  1.835006 -1.053245 -2.562826
#
# ...

# %%
new_dt.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    58507.284916 -0.166919  0.025564  0.569748  0.182598 -0.118340
# 1.0    56303.567039 -6.025123  4.401259 -7.982396  4.882663 -4.383916
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.000889 -0.043591 -0.015163  0.055275  ...  0.004565  0.019204
# 1.0   -1.448126 -7.031758  0.774862 -2.874111  ...  0.413668  0.766540
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.105407 -0.004043  0.021144  0.116073 -0.006587 -0.014175 -0.003522
# 1.0   -0.017387 -0.044248 -0.075042  0.080196  0.036588  0.182343  0.044561
#
#            Amount
# Class
# 0.0     84.614832
# 1.0    111.608492
#
# [2 rows x 30 columns]

# %%
new_dt['Class'].value_counts()
# Out:
# 0.0    358
# 1.0    358
# Name: Class, dtype: int64

# %%
x=new_dt.drop(columns='Class',axis=1)
y=new_dt['Class']

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 66819    52234.0  1.213291  0.226833  0.255260  0.654018 -0.283934 -0.629686
# 18551    29590.0  1.404845 -0.958269 -0.613266 -1.797737  1.009978  3.535838
# 26740    34228.0 -0.029427  0.354226 -0.119607 -2.096272  0.698008 -0.559983
# 78087    57366.0  1.118602 -0.253348  1.339775  0.805368 -1.189316 -0.115294
# 99126    66975.0  1.217849 -0.776929  0.099732 -0.488724 -1.158348 -1.126549
# ...          ...       ...       ...       ...       ...       ...       ...
# 157868  110547.0 -1.532810  2.232752 -5.923100  3.386708 -0.153443 -1.419748
# 157871  110552.0 -2.450367  2.107729 -5.140663  1.411304 -1.690780 -0.736427
# 157918  110617.0 -1.101035 -1.674928 -0.573388  5.617556  0.765556  0.440607
# 163149  115691.0 -1.550273  1.088689 -2.393388  1.008733 -1.087562 -1.104602
# 163586  116067.0  0.949241  1.333519 -4.855402  1.835006 -1.053245 -2.562826
#
# ...

# %%
scaler=StandardScaler()

# %%
std_data=scaler.fit_transform(x)

# %%
print(std_data)
# Out:
# [[-0.18362158  0.7033737  -0.49522834 ... -0.08811697  0.01017219
#   -0.39262701]
#  [-0.98764102  0.7346394  -0.79065865 ... -0.04148707  0.00238655
#   -0.29651979]
#  [-0.82295977  0.500535   -0.46347072 ...  0.31076432  0.5512914
#   -0.33703081]
#  ...
#  [ 1.88938085  0.32562514 -0.96931252 ... -0.04521401 -1.96878117
#    2.17757183]
#  [ 2.06954312  0.25229983 -0.28037887 ... -0.05325955 -0.22687385
#   -0.32867719]
#  [ 2.08289374  0.66027488 -0.21934581 ...  0.48726032  0.6809462
#   -0.13427298]]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression()
classifier.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_pred=classifier.predict(X_train)
train_accuracy=accuracy_score(Y_train,X_train_pred)
X_test_pred=classifier.predict(X_test)
test_accuracy=accuracy_score(Y_test,X_test_pred)

# %%
print(train_accuracy)
print(test_accuracy)
# Out:
# 0.9458041958041958
# 0.9444444444444444

# %%
first_row = x.iloc[0]
print(first_row)
# Out:
# Time      52234.000000
# V1            1.213291
# V2            0.226833
# V3            0.255260
# V4            0.654018
# V5           -0.283934
# V6           -0.629686
# V7           -0.067377
# V8           -0.001717
# V9            0.197737
# V10          -0.293797
# V11          -0.035220
# V12          -0.273139
# V13          -0.909406
# V14          -0.037303
# V15           1.468206
# V16           0.238368
# V17           0.336781
# V18          -0.611327
# V19          -0.549049
# V20          -0.184986
# V21          -0.273113
# V22          -0.806639
# V23           0.172683
# V24           0.003356
# V25           0.105724
# V26           0.127910
# V27          -0.013788
# V28           0.024928
# Amount        1.290000
# Name: 66819, dtype: float64

# %%
prediction=classifier.predict([[52234.000000,1.213291,0.226833,0.255260,0.654018,-0.283934,-0.629686,-0.067377,-0.001717,0.197737,-0.293797,-0.035220,-0.273139,-0.909406,-0.037303,1.468206,0.238368,0.336781,-0.611327,-0.549049,-0.184986,-0.273113,-0.806639,0.172683,0.003356,0.105724,0.127910,-0.013788,0.024928,1.290000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [0.]

# %%
if(prediction[0]==0):
  print("is legit")
else:
  print("its fraud")
# Out:
# is legit
